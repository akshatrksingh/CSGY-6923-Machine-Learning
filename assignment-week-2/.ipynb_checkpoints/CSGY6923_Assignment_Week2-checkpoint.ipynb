# %% [markdown]
# # CSGY6923_Assignment_Week2
# # Name: Akshat Singh

# %% [markdown]
# ### 1. Download the sample Python code that comes with the assigned textbook, Python Machine Learning.
#
# ### 2. Use the Iris dataset that's referenced in the text.
#
# ### 3. You can use the sample code from the text as a starting point or you can write your own code from scratch.

# %% [markdown]
# #### Reading the iris data

# %%
import os
import pandas as pd


s = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
print('URL:', s)

df = pd.read_csv(s,
                 header=None,
                 encoding='utf-8')

df.head()
# Out:
# URL: https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
df.shape[0], df[4].unique()
# Out:
# (150,
#  array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object))

# %% [markdown]
# ### An object-oriented perceptron API

# %%
import numpy as np


class Perceptron(object):
    """Perceptron classifier.

    Parameters
    ------------
    eta : float
      Learning rate (between 0.0 and 1.0)
    n_iter : int
      Passes over the training dataset.
    random_state : int
      Random number generator seed for random weight
      initialization.

    Attributes
    -----------
    w_ : 1d-array
      Weights after fitting.
    errors_ : list
      Number of misclassifications (updates) in each epoch.

    """
    def __init__(self, eta=0.01, n_iter=50, random_state=1):
        self.eta = eta
        self.n_iter = n_iter
        self.random_state = random_state

    def fit(self, X, y):
        """Fit training data.

        Parameters
        ----------
        X : {array-like}, shape = [n_examples, n_features]
          Training vectors, where n_examples is the number of examples and
          n_features is the number of features.
        y : array-like, shape = [n_examples]
          Target values.

        Returns
        -------
        self : object

        """
        rgen = np.random.RandomState(self.random_state)
        self.w_ = rgen.normal(loc=0.0, scale=0.01, size=1 + X.shape[1])
        self.errors_ = []

        for _ in range(self.n_iter):
            errors = 0
            for xi, target in zip(X, y):
                update = self.eta * (target - self.predict(xi))
                self.w_[1:] += update * xi
                self.w_[0] += update
                errors += int(update != 0.0)
            self.errors_.append(errors)
        return self

    def net_input(self, X):
        """Calculate net input"""
        return np.dot(X, self.w_[1:]) + self.w_[0]

    def predict(self, X):
        """Return class label after unit step"""
        return np.where(self.net_input(X) >= 0.0, 1, -1)

# %% [markdown]
# #### An object-oriented adaline API

# %%
class AdalineGD(object):
    """ADAptive LInear NEuron classifier.

    Parameters
    ------------
    eta : float
      Learning rate (between 0.0 and 1.0)
    n_iter : int
      Passes over the training dataset.
    random_state : int
      Random number generator seed for random weight
      initialization.


    Attributes
    -----------
    w_ : 1d-array
      Weights after fitting.
    cost_ : list
      Sum-of-squares cost function value in each epoch.

    """
    def __init__(self, eta=0.01, n_iter=50, random_state=1):
        self.eta = eta
        self.n_iter = n_iter
        self.random_state = random_state

    def fit(self, X, y):
        """ Fit training data.

        Parameters
        ----------
        X : {array-like}, shape = [n_examples, n_features]
          Training vectors, where n_examples is the number of examples and
          n_features is the number of features.
        y : array-like, shape = [n_examples]
          Target values.

        Returns
        -------
        self : object

        """
        rgen = np.random.RandomState(self.random_state)
        self.w_ = rgen.normal(loc=0.0, scale=0.01, size=1 + X.shape[1])
        self.cost_ = []

        for i in range(self.n_iter):
            net_input = self.net_input(X)
            # Please note that the "activation" method has no effect
            # in the code since it is simply an identity function. We
            # could write `output = self.net_input(X)` directly instead.
            # The purpose of the activation is more conceptual, i.e.,  
            # in the case of logistic regression (as we will see later), 
            # we could change it to
            # a sigmoid function to implement a logistic regression classifier.
            output = self.activation(net_input)
            errors = (y - output)
            self.w_[1:] += self.eta * X.T.dot(errors)
            self.w_[0] += self.eta * errors.sum()
            cost = (errors**2).sum() / 2.0
            self.cost_.append(cost)
        return self

    def net_input(self, X):
        """Calculate net input"""
        return np.dot(X, self.w_[1:]) + self.w_[0]

    def activation(self, X):
        """Compute linear activation"""
        return X

    def predict(self, X):
        """Return class label after unit step"""
        return np.where(self.activation(self.net_input(X)) >= 0.0, 1, -1)

# %% [markdown]
# ### 4. Pick two classes of data (i.e., two species of Iris) and two features from the four in the dataset, so that the data for two species are linearly separable using the features that you have chosen.
#
# ### Then Apply the Perceptron and Adaline models to the classes/feature that you have chosen and report your results.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# select setosa and versicolor
y = df.iloc[0:100, 4].values
y = np.where(y == 'Iris-setosa', -1, 1)

# extract sepal width and petal width
X = df.iloc[0:100, [1, 3]].values

# plot data
plt.scatter(X[:50, 0], X[:50, 1],
            color='blue', marker='o', label='setosa')
plt.scatter(X[50:100, 0], X[50:100, 1],
            color='red', marker='x', label='versicolor')

plt.xlabel('sepal width [cm]')
plt.ylabel('petal width [cm]')
plt.legend(loc='upper right')

plt.show()

# %% [markdown]
# #### I pick setosa and versicolor as the two classes of data (i.e., two species of Iris) and sepal width and petal width as the two features from the four in the dataset, so that the data for two species are linearly separable using the features that I have chosen.

# %% [markdown]
# #### Training the perceptron model

# %%
ppn = Perceptron(eta=0.0001, n_iter=50)

ppn.fit(X, y)

plt.plot(range(1, len(ppn.errors_) + 1), ppn.errors_, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Number of updates')

plt.show()

# %% [markdown]
# #### Plotting the decision regions

# %%
from matplotlib.colors import ListedColormap


def plot_decision_regions(X, y, classifier, resolution=0.02):

    # setup marker generator and color map
    markers = ('s', 'x', 'o', '^', 'v')
    colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])

    # plot the decision surface
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                           np.arange(x2_min, x2_max, resolution))
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.3, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())

    # plot class examples
    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], 
                    y=X[y == cl, 1],
                    alpha=0.8, 
                    c=colors[idx],
                    marker=markers[idx], 
                    label=cl, 
                    edgecolor='black')

# %%
plot_decision_regions(X, y, classifier=ppn)
plt.xlabel('sepal width [cm]')
plt.ylabel('petal width [cm]')
plt.legend(loc='upper right')

plt.show()
# Out:
# /var/folders/s5/wp8qnfd97ws66ytfq41vprzc0000gn/T/ipykernel_10987/1032177424.py:24: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(x=X[y == cl, 0],

# %% [markdown]
# #### What percentage of classifications are correct?

# %%
correct = 0
incorrect = 0
for i, j in zip(X, y):
    if ppn.predict(i) == j:
        correct += 1
    else:
        incorrect += 1
total = correct + incorrect
print(f"Percentage of correct classifications: {correct/total*100}")
print(f"Percentage of incorrect classifications: {incorrect/total*100}")
# Out:
# Percentage of correct classifications: 100.0
# Percentage of incorrect classifications: 0.0

# %% [markdown]
# #### Training the adaline model

# %%
ada = AdalineGD(eta=0.0001, n_iter=50)

ada.fit(X, y)

plt.plot(range(1, len(ada.cost_) + 1), ada.cost_, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Sum-squared-error')

plt.show()

# %% [markdown]
# #### Plotting the decision regions

# %%
plot_decision_regions(X, y, classifier=ada)
plt.title('Adaline - Gradient Descent')
plt.xlabel('sepal width')
plt.ylabel('petal width')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/s5/wp8qnfd97ws66ytfq41vprzc0000gn/T/ipykernel_10987/1032177424.py:24: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(x=X[y == cl, 0],

# %% [markdown]
# #### What percentage of classifications were correct?

# %%
correct = 0
incorrect = 0
for i, j in zip(X, y):
    if ada.predict(i) == j:
        correct += 1
    else:
        incorrect += 1
total = correct + incorrect
print(f"Percentage of correct classifications: {correct/total*100}")
print(f"Percentage of incorrect classifications: {incorrect/total*100}")
# Out:
# Percentage of correct classifications: 100.0
# Percentage of incorrect classifications: 0.0

# %% [markdown]
# ### 5. Repeat Step 4) using three features at a time.

# %%
# select setosa and versicolor
y = df.iloc[0:100, 4].values
y = np.where(y == 'Iris-setosa', -1, 1)

X = df.iloc[0:100, [0, 1, 2]].values
X1 = df.iloc[0:100, [0, 1]].values
X2 = df.iloc[0:100, [1, 2]].values
X3 = df.iloc[0:100, [2, 0]].values

# plot data
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
ax[0].scatter(X1[:50, 0], X1[:50, 1],
            color='blue', marker='o', label='setosa')
ax[0].scatter(X1[50:100, 0], X1[50:100, 1],
            color='red', marker='x', label='versicolor')

ax[0].set_xlabel('sepal length [cm]')
ax[0].set_ylabel('sepal width [cm]')
ax[0].legend(loc='upper right')

ax[1].scatter(X2[:50, 0], X2[:50, 1],
            color='blue', marker='o', label='setosa')
ax[1].scatter(X2[50:100, 0], X2[50:100, 1],
            color='red', marker='x', label='versicolor')

ax[1].set_xlabel('sepal width[cm]')
ax[1].set_ylabel('petal length [cm]')
ax[1].legend(loc='upper right')

ax[2].scatter(X3[:50, 0], X3[:50, 1],
            color='blue', marker='o', label='setosa')
ax[2].scatter(X3[50:100, 0], X3[50:100, 1],
            color='red', marker='x', label='versicolor')

ax[2].set_xlabel('petal length [cm]')
ax[2].set_ylabel('sepal length [cm]')
ax[2].legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### I pick setosa and versicolor as the two classes of data (i.e., two species of Iris) and sepal width, sepal length, and petal width as the three features from the four in the dataset, so that the data for two species are linearly separable using the features that I have chosen.

# %% [markdown]
# #### Training the perceptron model

# %%
ppn = Perceptron(eta=0.0001, n_iter=50)

ppn.fit(X, y)

plt.plot(range(1, len(ppn.errors_) + 1), ppn.errors_, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Number of updates')

plt.show()

# %% [markdown]
# #### What percentage of classifications were correct?

# %%
correct = 0
incorrect = 0
for i, j in zip(X, y):
    if ppn.predict(i) == j:
        correct += 1
    else:
        incorrect += 1
total = correct + incorrect
print(f"Percentage of correct classifications: {correct/total*100}")
print(f"Percentage of incorrect classifications: {incorrect/total*100}")
# Out:
# Percentage of correct classifications: 100.0
# Percentage of incorrect classifications: 0.0

# %% [markdown]
# #### Training the adaline model

# %%
ada = AdalineGD(eta=0.0001, n_iter=50)

ada.fit(X, y)

plt.plot(range(1, len(ada.cost_) + 1), ada.cost_, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Sum-squared-error')

plt.show()

# %% [markdown]
# #### What percentage of classifications were correct?

# %%
correct = 0
incorrect = 0
for i, j in zip(X, y):
    if ada.predict(i) == j:
        correct += 1
    else:
        incorrect += 1
total = correct + incorrect
print(f"Percentage of correct classifications: {correct/total*100}")
print(f"Percentage of incorrect classifications: {incorrect/total*100}")
# Out:
# Percentage of correct classifications: 100.0
# Percentage of incorrect classifications: 0.0

# %% [markdown]
# ### 6. Repeat Step 4) using all four features at a time.

# %%
# select setosa and versicolor
y = df.iloc[0:100, 4].values
y = np.where(y == 'Iris-setosa', -1, 1)

# extract sepal width and petal width
X = df.iloc[0:100, [0, 1, 2, 3]].values
X1 = df.iloc[0:100, [0, 1]].values
X2 = df.iloc[0:100, [1, 2]].values
X3 = df.iloc[0:100, [2, 3]].values
X4 = df.iloc[0:100, [3, 0]].values

# plot data
fig, ax = plt.subplots(1, 4, figsize=(15, 5))
ax[0].scatter(X1[:50, 0], X1[:50, 1],
            color='blue', marker='o', label='setosa')
ax[0].scatter(X1[50:100, 0], X1[50:100, 1],
            color='red', marker='x', label='versicolor')

ax[0].set_xlabel('sepal length [cm]')
ax[0].set_ylabel('sepal width [cm]')
ax[0].legend(loc='upper right')

ax[1].scatter(X2[:50, 0], X2[:50, 1],
            color='blue', marker='o', label='setosa')
ax[1].scatter(X2[50:100, 0], X2[50:100, 1],
            color='red', marker='x', label='versicolor')

ax[1].set_xlabel('sepal width[cm]')
ax[1].set_ylabel('petal length [cm]')
ax[1].legend(loc='upper right')

ax[2].scatter(X3[:50, 0], X3[:50, 1],
            color='blue', marker='o', label='setosa')
ax[2].scatter(X3[50:100, 0], X3[50:100, 1],
            color='red', marker='x', label='versicolor')

ax[2].set_xlabel('petal length [cm]')
ax[2].set_ylabel('petal width [cm]')
ax[2].legend(loc='upper right')

ax[3].scatter(X4[:50, 0], X4[:50, 1],
            color='blue', marker='o', label='setosa')
ax[3].scatter(X4[50:100, 0], X4[50:100, 1],
            color='red', marker='x', label='versicolor')

ax[3].set_xlabel('petal width [cm]')
ax[3].set_ylabel('sepal length [cm]')
ax[3].legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Training the perceptron model

# %%
ppn = Perceptron(eta=0.0001, n_iter=50)

ppn.fit(X, y)

plt.plot(range(1, len(ppn.errors_) + 1), ppn.errors_, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Number of updates')

plt.show()

# %% [markdown]
# #### What percentage of classifications are correct?

# %%
correct = 0
incorrect = 0
for i, j in zip(X, y):
    if ppn.predict(i) == j:
        correct += 1
    else:
        incorrect += 1
total = correct + incorrect
print(f"Percentage of correct classifications: {correct/total*100}")
print(f"Percentage of incorrect classifications: {incorrect/total*100}")
# Out:
# Percentage of correct classifications: 100.0
# Percentage of incorrect classifications: 0.0

# %% [markdown]
# #### Training the adaline model

# %%
ada = AdalineGD(eta=0.0001, n_iter=50)

ada.fit(X, y)

plt.plot(range(1, len(ada.cost_) + 1), ada.cost_, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Sum-squared-error')

plt.show()

# %% [markdown]
# #### What percentage of classifications were correct?

# %%
correct = 0
incorrect = 0
for i, j in zip(X, y):
    if ada.predict(i) == j:
        correct += 1
    else:
        incorrect += 1
total = correct + incorrect
print(f"Percentage of correct classifications: {correct/total*100}")
print(f"Percentage of incorrect classifications: {incorrect/total*100}")
# Out:
# Percentage of correct classifications: 100.0
# Percentage of incorrect classifications: 0.0

# %% [markdown]
# ### 7. Pick two classes of data (i.e., two species of Iris) and two features from the four in the dataset, so that the data for two species are NOT linearly separable using the features that you have chosen.
#
# ### Then Apply the Perceptron and Adaline models to the classes/features that you have chosen and report your results.

# %%
# select versicolor and virginica
y = df.iloc[50:, 4].values
y = np.where(y == 'Iris-versicolor', -1, 1)

# extract sepal length and petal width
X = df.iloc[50:, [0, 3]].values

# plot data
plt.scatter(X[:50, 0], X[:50, 1],
            color='red', marker='o', label='versicolor')
plt.scatter(X[50:, 0], X[50:, 1],
            color='blue', marker='x', label='virginica')

plt.xlabel('sepal length [cm]')
plt.ylabel('petal width [cm]')
plt.legend(loc='upper left')

plt.show()

# %% [markdown]
# #### I pick versicolor and virginica as the two classes of data (i.e., two species of Iris) and sepal length and petal width as the two features from the four in the dataset, so that the data for two species are not linearly separable using the features that I have chosen.

# %% [markdown]
# #### Training the perceptron model

# %%
ppn = Perceptron(eta=0.0001, n_iter=100)

ppn.fit(X, y)

plt.plot(range(1, len(ppn.errors_) + 1), ppn.errors_, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Number of updates')

plt.show()

# %% [markdown]
# #### Plotting the decision regions

# %%
plot_decision_regions(X, y, classifier=ppn)
plt.xlabel('sepal length [cm]')
plt.ylabel('petal width [cm]')
plt.legend(loc='upper right')

plt.show()
# Out:
# /var/folders/s5/wp8qnfd97ws66ytfq41vprzc0000gn/T/ipykernel_10987/1032177424.py:24: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(x=X[y == cl, 0],

# %%
correct = 0
incorrect = 0
for i, j in zip(X, y):
    if ppn.predict(i) == j:
        correct += 1
    else:
        incorrect += 1
total = correct + incorrect
print(f"Percentage of correct classifications: {correct/total*100}")
print(f"Percentage of incorrect classifications: {incorrect/total*100}")
# Out:
# Percentage of correct classifications: 50.0
# Percentage of incorrect classifications: 50.0

# %% [markdown]
# #### Training the adaline model

# %%
ada = AdalineGD(eta=0.0001, n_iter=100)

ada.fit(X, y)

plt.plot(range(1, len(ada.cost_) + 1), ada.cost_, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Sum-squared-error')

plt.show()

# %% [markdown]
# #### Plotting the decision regions

# %%
plot_decision_regions(X, y, classifier=ada)
plt.xlabel('sepal length [cm]')
plt.ylabel('petal width [cm]')
plt.legend(loc='upper right')

plt.show()
# Out:
# /var/folders/s5/wp8qnfd97ws66ytfq41vprzc0000gn/T/ipykernel_10987/1032177424.py:24: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(x=X[y == cl, 0],

# %%
correct = 0
incorrect = 0
for i, j in zip(X, y):
    if ada.predict(i) == j:
        correct += 1
    else:
        incorrect += 1
total = correct + incorrect
print(f"Percentage of correct classifications: {correct/total*100}")
print(f"Percentage of incorrect classifications: {incorrect/total*100}")
# Out:
# Percentage of correct classifications: 78.0
# Percentage of incorrect classifications: 22.0

# %% [markdown]
# ### 8. Repeat Step 7) using three features at a time.

# %%
# select setosa and versicolor
y = df.iloc[50:, 4].values
y = np.where(y == 'Iris-versicolor', -1, 1)

# extract sepal width and petal width
X = df.iloc[50:, [0, 1, 2]].values
X1 = df.iloc[50:, [0, 1]].values
X2 = df.iloc[50:, [1, 2]].values
X3 = df.iloc[50:, [2, 0]].values

# plot data
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
ax[0].scatter(X1[:50, 0], X1[:50, 1],
            color='blue', marker='o', label='versicolor')
ax[0].scatter(X1[50:100, 0], X1[50:100, 1],
            color='red', marker='x', label='virginica')

ax[0].set_xlabel('sepal length[cm]')
ax[0].set_ylabel('sepal width[cm]')
ax[0].legend(loc='upper right')

ax[1].scatter(X2[:50, 0], X2[:50, 1],
            color='blue', marker='o', label='versicolor')
ax[1].scatter(X2[50:100, 0], X2[50:100, 1],
            color='red', marker='x', label='virginica')

ax[1].set_xlabel('sepal width[cm]')
ax[1].set_ylabel('petal length [cm]')
ax[1].legend(loc='upper right')

ax[2].scatter(X3[:50, 0], X3[:50, 1],
            color='blue', marker='o', label='versicolor')
ax[2].scatter(X3[50:100, 0], X3[50:100, 1],
            color='red', marker='x', label='virginica')

ax[2].set_xlabel('petal length [cm]')
ax[2].set_ylabel('sepal length [cm]')
ax[2].legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### I pick versicolor and virginica as the two classes of data (i.e., two species of Iris) and sepal width, sepal length, and petal width as the three features from the four in the dataset, so that the data for two species are linearly separable using the features that I have chosen.

# %% [markdown]
# #### Training the perceptron model

# %%
ppn = Perceptron(eta=0.0001, n_iter=100)

ppn.fit(X, y)

plt.plot(range(1, len(ppn.errors_) + 1), ppn.errors_, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Number of updates')

plt.show()

# %% [markdown]
# #### What percentage of classifications were correct?

# %%
correct = 0
incorrect = 0
for i, j in zip(X, y):
    if ppn.predict(i) == j:
        correct += 1
    else:
        incorrect += 1
total = correct + incorrect
print(f"Percentage of correct classifications: {correct/total*100}")
print(f"Percentage of incorrect classifications: {incorrect/total*100}")
# Out:
# Percentage of correct classifications: 54.0
# Percentage of incorrect classifications: 46.0

# %% [markdown]
# #### Training the adaline model

# %%
ada = AdalineGD(eta=0.0001, n_iter=100)

ada.fit(X, y)

plt.plot(range(1, len(ada.cost_) + 1), ada.cost_, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Sum-squared-error')

plt.show()

# %%
correct = 0
incorrect = 0
for i, j in zip(X, y):
    if ada.predict(i) == j:
        correct += 1
    else:
        incorrect += 1
total = correct + incorrect
print(f"Percentage of correct classifications: {correct/total*100}")
print(f"Percentage of incorrect classifications: {incorrect/total*100}")
# Out:
# Percentage of correct classifications: 89.0
# Percentage of incorrect classifications: 11.0

# %% [markdown]
# #### 9. Repeat Step 7) using all four feature at the same time.

# %%
# select setosa and versicolor
y = df.iloc[50:, 4].values
y = np.where(y == 'Iris-versicolor', -1, 1)

# extract sepal width and petal width
X = df.iloc[50:, [0, 1, 2, 3]].values
X1 = df.iloc[50:, [0, 1]].values
X2 = df.iloc[50:, [1, 2]].values
X3 = df.iloc[50:, [2, 3]].values
X4 = df.iloc[50:, [3, 0]].values

# plot data
fig, ax = plt.subplots(1, 4, figsize=(15, 5))
ax[0].scatter(X1[:50, 0], X1[:50, 1],
            color='blue', marker='o', label='versicolor')
ax[0].scatter(X1[50:100, 0], X1[50:100, 1],
            color='red', marker='x', label='virginica')

ax[0].set_xlabel('sepal length [cm]')
ax[0].set_ylabel('sepal width [cm]')
ax[0].legend(loc='upper right')

ax[1].scatter(X2[:50, 0], X2[:50, 1],
            color='blue', marker='o', label='versicolor')
ax[1].scatter(X2[50:100, 0], X2[50:100, 1],
            color='red', marker='x', label='virginica')

ax[1].set_xlabel('sepal width [cm]')
ax[1].set_ylabel('petal length [cm]')
ax[1].legend(loc='upper right')

ax[2].scatter(X3[:50, 0], X3[:50, 1],
            color='blue', marker='o', label='versicolor')
ax[2].scatter(X3[50:100, 0], X3[50:100, 1],
            color='red', marker='x', label='virginica')

ax[2].set_xlabel('petal length [cm]')
ax[2].set_ylabel('petal width [cm]')
ax[2].legend(loc='upper right')

ax[3].scatter(X4[:50, 0], X4[:50, 1],
            color='blue', marker='o', label='versicolor')
ax[3].scatter(X4[50:100, 0], X4[50:100, 1],
            color='red', marker='x', label='virginica')

ax[3].set_xlabel('petal width [cm]')
ax[3].set_ylabel('sepal length [cm]')
ax[3].legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Training the perceptron model

# %%
ppn = Perceptron(eta=0.0001, n_iter=100)

ppn.fit(X, y)

plt.plot(range(1, len(ppn.errors_) + 1), ppn.errors_, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Number of updates')

plt.show()

# %% [markdown]
# #### What percentage of classifications were correct?

# %%
correct = 0
incorrect = 0
for i, j in zip(X, y):
    if ppn.predict(i) == j:
        correct += 1
    else:
        incorrect += 1
total = correct + incorrect
print(f"Percentage of correct classifications: {correct/total*100}")
print(f"Percentage of incorrect classifications: {incorrect/total*100}")
# Out:
# Percentage of correct classifications: 52.0
# Percentage of incorrect classifications: 48.0

# %% [markdown]
# #### Training the adaline model

# %%
ada = AdalineGD(eta=0.0001, n_iter=100)

ada.fit(X, y)

plt.plot(range(1, len(ada.cost_) + 1), ada.cost_, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Sum-squared-error')

plt.show()

# %% [markdown]
# #### What percentage of classifications were correct?

# %%
correct = 0
incorrect = 0
for i, j in zip(X, y):
    if ada.predict(i) == j:
        correct += 1
    else:
        incorrect += 1
total = correct + incorrect
print(f"Percentage of correct classifications: {correct/total*100}")
print(f"Percentage of incorrect classifications: {incorrect/total*100}")
# Out:
# Percentage of correct classifications: 92.0
# Percentage of incorrect classifications: 8.0

# %% [markdown]
# ### 10. Compare your results for the Perceptron and Adaline models.

# %% [markdown]
# #### As evident from the percentage of correct and incorrect classifications, in case of linearly separable data, both perceptron and adaline model perform well. But in case of data that are not linearly separable, the adaline model performs signficantly better than the perceptron model.
